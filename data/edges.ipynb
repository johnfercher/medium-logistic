# %% [markdown]
# ## Imports

# %%
import pandas as pd

# %% [markdown]
# ## Load Data

# %%
df = pd.read_csv('edges.csv')
df
# Out:
#             source          target  distance
# 0       rio_branco     porto_velho       510
# 1           manaus       boa_vista       748
# 2           manaus          macapa      2993
# 3           manaus           belem      2994
# 4           manaus          cuiaba      2349
# 5           manaus     porto_velho       889
# 6           macapa           belem       527
# 7            belem        sao_luis       582
# 8            belem          palmas      1211
# 9         sao_luis       fortaleza       904
# 10        sao_luis        teresina       436
# 11       fortaleza           natal       522
# 12       fortaleza        teresina       604
# 13       fortaleza     joao_pessoa       671
# 14           natal     joao_pessoa       181
# 15           natal        teresina      1055
# 16     joao_pessoa          recife       116
# 17     joao_pessoa        teresina      1156
# 18          recife          maceio       257
# 19          recife        teresina      1128
# ...
